# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import time

# %%
# Load dataset
data = pd.read_csv('GOOGL.csv')

# %%
print(len(data))
# Out:
# 4431

# %%
plt.figure(figsize=(10, 6))
plt.plot(data['Close'], label='Google Stock Price')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.title('Google Stock Price Over Time')
plt.legend()
plt.show()

# %%
# Normalize data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(np.array(data['Close']).reshape(-1, 1))

# %%
# Split data into train and test sets
train_size = int(len(scaled_data) * 0.8)
train_data = scaled_data[:train_size]
test_data = scaled_data[train_size:]

# %%
# Function to create dataset with time steps
def create_dataset(data, time_step):
    X, y = [], []
    for i in range(len(data) - time_step - 1):
        X.append(data[i:(i + time_step), 0])
        y.append(data[i + time_step, 0])
    return np.array(X), np.array(y)

# %%
# Define time steps and create train and test datasets
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# %%
# Reshape data for LSTM input [samples, time steps, features]
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
# Build LSTM model
model = Sequential([
    LSTM(50, return_sequences=True, input_shape=(time_step, 1)),
    LSTM(50),
    Dense(1)
])
# Out:
# 2025-04-22 14:06:53.155830: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# /home/admin1/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Compile model
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# Measure training time
start_time = time.time()

# %%
# Train model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=64, verbose=1)
# Out:
# Epoch 1/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - loss: 0.0061 - val_loss: 6.0095e-04
# Epoch 2/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 5.5254e-05 - val_loss: 5.9462e-04
# Epoch 3/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 4.6105e-05 - val_loss: 7.1677e-04
# Epoch 4/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - loss: 4.1834e-05 - val_loss: 0.0011
# Epoch 5/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 4.0042e-05 - val_loss: 0.0013
# Epoch 6/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 4.3677e-05 - val_loss: 0.0013
# Epoch 7/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 3.8401e-05 - val_loss: 0.0012
# Epoch 8/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 3.7641e-05 - val_loss: 0.0012
# Epoch 9/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 3.9775e-05 - val_loss: 9.1946e-04
# Epoch 10/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 4.2615e-05 - val_loss: 0.0011
# Epoch 11/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - loss: 3.8355e-05 - val_loss: 0.0013
# Epoch 12/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - loss: 3.7927e-05 - val_loss: 9.1835e-04
# Epoch 13/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - loss: 3.5859e-05 - val_loss: 0.0012
# Epoch 14/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - loss: 3.8579e-05 - val_loss: 8.6544e-04
# Epoch 15/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 3.6948e-05 - val_loss: 0.0012
# Epoch 16/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 3.3693e-05 - val_loss: 7.2617e-04
# Epoch 17/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 3.4262e-05 - val_loss: 9.4048e-04
# Epoch 18/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 3.1359e-05 - val_loss: 7.0933e-04
# Epoch 19/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 3.1430e-05 - val_loss: 0.0010
# Epoch 20/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - loss: 3.0626e-05 - val_loss: 0.0010
# Epoch 21/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 3.3798e-05 - val_loss: 6.7227e-04
# Epoch 22/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 3.1861e-05 - val_loss: 5.6470e-04
# Epoch 23/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 3.8705e-05 - val_loss: 6.1052e-04
# Epoch 24/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 3.2170e-05 - val_loss: 4.9221e-04
# Epoch 25/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - loss: 4.0879e-05 - val_loss: 7.8013e-04
# Epoch 26/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 3.4913e-05 - val_loss: 5.5737e-04
# Epoch 27/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 3.4167e-05 - val_loss: 6.2842e-04
# Epoch 28/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - loss: 3.2931e-05 - val_loss: 0.0011
# Epoch 29/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 3.1603e-05 - val_loss: 7.2491e-04
# Epoch 30/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 3.6335e-05 - val_loss: 7.7803e-04
# Epoch 31/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 2.8759e-05 - val_loss: 7.3785e-04
# Epoch 32/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 2.8339e-05 - val_loss: 4.7901e-04
# Epoch 33/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - loss: 2.7234e-05 - val_loss: 5.9420e-04
# Epoch 34/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 2.8331e-05 - val_loss: 6.6109e-04
# Epoch 35/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - loss: 3.0050e-05 - val_loss: 3.8158e-04
# Epoch 36/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 3.6609e-05 - val_loss: 4.1130e-04
# Epoch 37/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 3.0196e-05 - val_loss: 6.4444e-04
# Epoch 38/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 2.3221e-05 - val_loss: 9.7372e-04
# Epoch 39/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 2.6377e-05 - val_loss: 6.8496e-04
# Epoch 40/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - loss: 2.7789e-05 - val_loss: 7.6764e-04
# Epoch 41/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 2.5940e-05 - val_loss: 5.7975e-04
# Epoch 42/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 2.3220e-05 - val_loss: 4.3889e-04
# Epoch 43/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 2.5120e-05 - val_loss: 4.9823e-04
# Epoch 44/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 2.6788e-05 - val_loss: 7.7833e-04
# Epoch 45/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 2.8897e-05 - val_loss: 5.0907e-04
# Epoch 46/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 2.8762e-05 - val_loss: 6.7246e-04
# Epoch 47/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 2.5466e-05 - val_loss: 3.2196e-04
# Epoch 48/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - loss: 3.4068e-05 - val_loss: 5.2360e-04
# Epoch 49/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 2.3652e-05 - val_loss: 8.7071e-04
# Epoch 50/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 2.0271e-05 - val_loss: 8.2202e-04

# %%
training_time = time.time() - start_time
print("Training Time:", training_time, "seconds")
# Out:
# Training Time: 154.46751260757446 seconds

# %%
# Evaluate model
train_loss = model.evaluate(X_train, y_train, verbose=0)
test_loss = model.evaluate(X_test, y_test, verbose=0)
print('Train Loss:', train_loss)
print('Test Loss:', test_loss)
# Out:
# Train Loss: 2.2326892576529644e-05
# Test Loss: 0.0008220153977163136

# %%
# Measure prediction time
start_time = time.time()

# %%
# Predictions
train_predictions = model.predict(X_train)
test_predictions = model.predict(X_test)
# Out:
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %%
prediction_time = time.time() - start_time
print("Prediction Time:", prediction_time, "seconds")
# Out:
# Prediction Time: 13.226552486419678 seconds

# %%
# Inverse scaling to get original stock prices
train_predictions = scaler.inverse_transform(train_predictions)
y_train = scaler.inverse_transform([y_train])
test_predictions = scaler.inverse_transform(test_predictions)
y_test = scaler.inverse_transform([y_test])

# %%
# Plot predictions
plt.figure(figsize=(10, 6))
plt.plot(data.index[:len(train_predictions)], train_predictions, label='Train Predictions')
#plt.plot(data.index[len(train_predictions)+time_step:len(train_predictions)+time_step+len(test_predictions)], test_predictions, label='Test Predictions')
plt.plot(data.index[:len(y_train.flatten())], y_train.flatten(), label='Actual Train')
#plt.plot(data.index[len(y_train.flatten())+time_step:len(y_train.flatten())+time_step+len(y_test.flatten())], y_test.flatten(), label='Actual Test')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.title('Google Stock Price Prediction')
plt.legend()
plt.show()

# %%
# Plot predictions
plt.figure(figsize=(10, 6))
#plt.plot(data.index[:len(train_predictions)], train_predictions, label='Train Predictions')
plt.plot(data.index[len(train_predictions)+time_step:len(train_predictions)+time_step+len(test_predictions)], test_predictions, label='Test Predictions')
#plt.plot(data.index[:len(y_train.flatten())], y_train.flatten(), label='Actual Train')
plt.plot(data.index[len(y_train.flatten())+time_step:len(y_train.flatten())+time_step+len(y_test.flatten())], y_test.flatten(), label='Actual Test')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.title('Google Stock Price Prediction')
plt.legend()
plt.show()

# %%
# Plot predictions
plt.figure(figsize=(10, 6))
plt.plot(data.index[:len(train_predictions)], train_predictions, label='Train Predictions')
plt.plot(data.index[len(train_predictions)+time_step:len(train_predictions)+time_step+len(test_predictions)], test_predictions, label='Test Predictions')
plt.plot(data.index[:len(y_train.flatten())], y_train.flatten(), label='Actual Train')
plt.plot(data.index[len(y_train.flatten())+time_step:len(y_train.flatten())+time_step+len(y_test.flatten())], y_test.flatten(), label='Actual Test')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.title('Google Stock Price Prediction')
plt.legend()
plt.show()

# %% [markdown]
# <!-- This code demonstrates a simple example of how to build an LSTM-based RNN model for time series prediction using the Google stock prices dataset. Here's a brief overview of the steps:
#
# Load and visualize the dataset.
#
# Normalize the data to the range [0, 1].
#
# Split the data into train and test sets.
#
# Create sequences of data with specified time steps.
#
# Build an LSTM model with two LSTM layers and a Dense output layer.
#
# Compile the model with mean squared error loss and Adam optimizer.
#
# Train the model on the train data.
#
# Evaluate the model on both train and test data.
#
# Inverse scale the predictions to get the original stock prices.
#
# Plot the actual vs predicted stock prices for both train and test data. -->
